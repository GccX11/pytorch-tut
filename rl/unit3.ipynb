|
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.3e+03  |
# |    ep_rew_mean      | 650      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3788     |
# |    fps              | 543      |
# |    time_elapsed     | 1741     |
# |    total_timesteps  | 946315   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0318   |
# |    n_updates        | 211578   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.34e+03 |
# |    ep_rew_mean      | 660      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3792     |
# |    fps              | 543      |
# |    time_elapsed     | 1744     |
# |    total_timesteps  | 947929   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 211982   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.34e+03 |
# |    ep_rew_mean      | 660      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3796     |
# |    fps              | 543      |
# |    time_elapsed     | 1747     |
# |    total_timesteps  | 949685   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0208   |
# |    n_updates        | 212421   |
# ----------------------------------
# Eval num_timesteps=950000, episode_reward=703.00 +/- 179.93
# Episode length: 4425.40 +/- 1050.89
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.43e+03 |
# |    mean_reward      | 703      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 950000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0249   |
# |    n_updates        | 212499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.34e+03 |
# |    ep_rew_mean      | 658      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3800     |
# |    fps              | 541      |
# |    time_elapsed     | 1756     |
# |    total_timesteps  | 951280   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.017    |
# |    n_updates        | 212819   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.33e+03 |
# |    ep_rew_mean      | 654      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3804     |
# |    fps              | 541      |
# |    time_elapsed     | 1760     |
# |    total_timesteps  | 953755   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0471   |
# |    n_updates        | 213438   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.36e+03 |
# |    ep_rew_mean      | 661      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3808     |
# |    fps              | 541      |
# |    time_elapsed     | 1763     |
# |    total_timesteps  | 955478   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0207   |
# |    n_updates        | 213869   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.32e+03 |
# |    ep_rew_mean      | 655      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3812     |
# |    fps              | 541      |
# |    time_elapsed     | 1768     |
# |    total_timesteps  | 958336   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0243   |
# |    n_updates        | 214583   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.36e+03 |
# |    ep_rew_mean      | 660      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3816     |
# |    fps              | 541      |
# |    time_elapsed     | 1773     |
# |    total_timesteps  | 961034   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0382   |
# |    n_updates        | 215258   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.32e+03 |
# |    ep_rew_mean      | 654      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3820     |
# |    fps              | 541      |
# |    time_elapsed     | 1778     |
# |    total_timesteps  | 963631   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0152   |
# |    n_updates        | 215907   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.37e+03 |
# |    ep_rew_mean      | 659      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3824     |
# |    fps              | 541      |
# |    time_elapsed     | 1781     |
# |    total_timesteps  | 965601   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0128   |
# |    n_updates        | 216400   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.33e+03 |
# |    ep_rew_mean      | 658      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3828     |
# |    fps              | 541      |
# |    time_elapsed     | 1784     |
# |    total_timesteps  | 967371   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0118   |
# |    n_updates        | 216842   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.31e+03 |
# |    ep_rew_mean      | 655      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3832     |
# |    fps              | 542      |
# |    time_elapsed     | 1788     |
# |    total_timesteps  | 969297   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0128   |
# |    n_updates        | 217324   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.31e+03 |
# |    ep_rew_mean      | 653      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3836     |
# |    fps              | 542      |
# |    time_elapsed     | 1791     |
# |    total_timesteps  | 970863   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0386   |
# |    n_updates        | 217715   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.31e+03 |
# |    ep_rew_mean      | 652      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3840     |
# |    fps              | 542      |
# |    time_elapsed     | 1793     |
# |    total_timesteps  | 972356   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0741   |
# |    n_updates        | 218088   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.34e+03 |
# |    ep_rew_mean      | 657      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3844     |
# |    fps              | 542      |
# |    time_elapsed     | 1797     |
# |    total_timesteps  | 974646   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00825  |
# |    n_updates        | 218661   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=666.00 +/- 128.66
# Episode length: 4934.80 +/- 1260.17
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.93e+03 |
# |    mean_reward      | 666      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00834  |
# |    n_updates        | 218749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.35e+03 |
# |    ep_rew_mean      | 658      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3848     |
# |    fps              | 540      |
# |    time_elapsed     | 1806     |
# |    total_timesteps  | 975943   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00609  |
# |    n_updates        | 218985   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.36e+03 |
# |    ep_rew_mean      | 660      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3852     |
# |    fps              | 540      |
# |    time_elapsed     | 1810     |
# |    total_timesteps  | 978088   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0941   |
# |    n_updates        | 219521   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.37e+03 |
# |    ep_rew_mean      | 660      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3856     |
# |    fps              | 540      |
# |    time_elapsed     | 1812     |
# |    total_timesteps  | 979191   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0169   |
# |    n_updates        | 219797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.38e+03 |
# |    ep_rew_mean      | 664      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3860     |
# |    fps              | 540      |
# |    time_elapsed     | 1819     |
# |    total_timesteps  | 983333   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.018    |
# |    n_updates        | 220833   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.43e+03 |
# |    ep_rew_mean      | 669      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3864     |
# |    fps              | 540      |
# |    time_elapsed     | 1823     |
# |    total_timesteps  | 985217   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0315   |
# |    n_updates        | 221304   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.43e+03 |
# |    ep_rew_mean      | 669      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3868     |
# |    fps              | 540      |
# |    time_elapsed     | 1827     |
# |    total_timesteps  | 987386   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0543   |
# |    n_updates        | 221846   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.46e+03 |
# |    ep_rew_mean      | 669      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3872     |
# |    fps              | 540      |
# |    time_elapsed     | 1831     |
# |    total_timesteps  | 989905   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 222476   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.43e+03 |
# |    ep_rew_mean      | 662      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3876     |
# |    fps              | 540      |
# |    time_elapsed     | 1833     |
# |    total_timesteps  | 990790   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0274   |
# |    n_updates        | 222697   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.42e+03 |
# |    ep_rew_mean      | 659      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3880     |
# |    fps              | 540      |
# |    time_elapsed     | 1836     |
# |    total_timesteps  | 992688   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0118   |
# |    n_updates        | 223171   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.41e+03 |
# |    ep_rew_mean      | 660      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3884     |
# |    fps              | 540      |
# |    time_elapsed     | 1839     |
# |    total_timesteps  | 994618   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0242   |
# |    n_updates        | 223654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.39e+03 |
# |    ep_rew_mean      | 660      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3888     |
# |    fps              | 540      |
# |    time_elapsed     | 1841     |
# |    total_timesteps  | 995769   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0243   |
# |    n_updates        | 223942   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.39e+03 |
# |    ep_rew_mean      | 663      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3892     |
# |    fps              | 540      |
# |    time_elapsed     | 1846     |
# |    total_timesteps  | 998461   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0539   |
# |    n_updates        | 224615   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=722.00 +/- 81.28
# Episode length: 4128.20 +/- 258.44
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.13e+03 |
# |    mean_reward      | 722      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0191   |
# |    n_updates        | 224999   |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_3

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml

# %% [markdown]
# ## Let's evaluate our agent 👀
# - RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate our agent. In most RL libraries, we call the evaluation script `enjoy.py`.
# - Let's evaluate it for 5000 timesteps 🔥

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps _________  --folder logs/
# Out:
# usage: enjoy.py [-h] [--env ENV] [-f FOLDER]
#                 [--algo {a2c,ddpg,dqn,ppo,sac,td3,ars,qrdqn,tqc,trpo,ppo_lstm}]
#                 [-n N_TIMESTEPS] [--num-threads NUM_THREADS] [--n-envs N_ENVS]
#                 [--exp-id EXP_ID] [--verbose VERBOSE] [--no-render]
#                 [--deterministic] [--device DEVICE] [--load-best]
#                 [--load-checkpoint LOAD_CHECKPOINT] [--load-last-checkpoint]
#                 [--stochastic] [--norm-reward] [--seed SEED]
#                 [--reward-log REWARD_LOG]
#                 [--gym-packages GYM_PACKAGES [GYM_PACKAGES ...]]
#                 [--env-kwargs ENV_KWARGS [ENV_KWARGS ...]] [--custom-objects]
#                 [-P]
# enjoy.py: error: argument -n/--n-timesteps: invalid int value: '_________'

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# Loading latest experiment, id=3
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_3/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 800.00
# Atari Episode Length 3741
# Atari Episode Score: 545.00
# Atari Episode Length 3609
# Atari Episode Score: 1075.00
# Atari Episode Length 7185

# %% [markdown]
# ## Publish our trained model on the Hub 🚀
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/space-invaders-model.gif" alt="Space Invaders model">

# %% [markdown]
# By using `rl_zoo3.push_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# `-f`: Where the trained model folder is (in our case `logs`)
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/select-id.png" alt="Select Id">

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4 -orga GccX11 -f logs/
# Out:
# Loading latest experiment, id=3
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_3/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to GccX11/dqn-SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# /home/matt/anaconda3/envs/pytorch2/lib/python3.11/site-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# Cloning https://huggingface.co/GccX11/dqn-SpaceInvadersNoFrameskip-v4 into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/GccX11/dqn-SpaceInvadersNoFrameskip-v4 into local empty directory.
# Saving model to: hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4
# /home/matt/anaconda3/envs/pytorch2/lib/python3.11/site-packages/gymnasium/utils/passive_env_checker.py:364: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# Saving video to /tmp/tmpofqu5b4c/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmpofqu5b4c/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmpofqu5b4c/-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /tmp/tmpofqu5b4c/-step-0-to-step-1000.mp4
# ffmpeg version 9c33b2f Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 9.3.0 (crosstool-NG 1.24.0.133_b0863d8_dirty)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1627813612080/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/tmp/tmpofqu5b4c/-step-0-to-step-1000.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 00:00:33.40, start: 0.000000, bitrate: 58 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 160x210, 55 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55f47956a8c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55f47956a8c0] profile High, level 1.2, 4:2:0, 8-bit
# [libx264 @ 0x55f47956a8c0] 264 - core 161 r3030M 8bd6d28 - H.264/MPEG-4 AVC codec - Copyleft 2003-2020 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=7 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'hub/dqn-SpaceInvadersNoFrameskip-v4/replay.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 160x210, q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame= 1002 fps=0.0 q=-1.0 Lsize=     226kB time=00:00:33.30 bitrate=  55.6kbits/s speed= 109x
# video:215kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.225832%
# [libx264 @ 0x55f47956a8c0] frame I:5     Avg QP:15.55  size:  3641
# [libx264 @ 0x55f47956a8c0] frame P:451   Avg QP:21.99  size:   380
# [libx264 @ 0x55f47956a8c0] frame B:546   Avg QP:28.85  size:    54
# [libx264 @ 0x55f47956a8c0] consecutive B-frames: 21.1% 14.6% 12.9% 51.5%
# [libx264 @ 0x55f47956a8c0] mb I  I16..4: 35.7% 19.3% 45.0%
# [libx264 @ 0x55f47956a8c0] mb P  I16..4:  0.5%  0.9%  0.9%  P16..4:  9.0%  3.3%  2.0%  0.0%  0.0%    skip:83.5%
# [libx264 @ 0x55f47956a8c0] mb B  I16..4:  0.1%  0.1%  0.1%  B16..8: 10.1%  1.0%  0.1%  direct: 0.1%  skip:88.2%  L0:50.0% L1:49.5% BI: 0.5%
# [libx264 @ 0x55f47956a8c0] 8x8 transform intra:33.1% inter:5.8%
# [libx264 @ 0x55f47956a8c0] coded y,uvDC,uvAC intra: 24.8% 42.1% 38.9% inter: 1.5% 2.0% 1.7%
# [libx264 @ 0x55f47956a8c0] i16 v,h,dc,p: 54% 39%  7%  0%
# [libx264 @ 0x55f47956a8c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20%  6% 73%  1%  0%  0%  0%  0%  0%
# [libx264 @ 0x55f47956a8c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 12% 40%  2%  2%  3%  2%  2%  2%
# [libx264 @ 0x55f47956a8c0] i8c dc,h,v,p: 53% 30% 16%  2%
# [libx264 @ 0x55f47956a8c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55f47956a8c0] ref P L0: 77.2%  4.8%  9.3%  8.7%
# [libx264 @ 0x55f47956a8c0] ref B L0: 82.8% 14.2%  3.0%
# [libx264 @ 0x55f47956a8c0] ref B L1: 96.5%  3.5%
# [libx264 @ 0x55f47956a8c0] kb/s:52.49
# ℹ Pushing repo dqn-SpaceInvadersNoFrameskip-v4 to the Hugging Face
# Hub
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:   0%| | 1.00/26.0M [00:00<?, ?B
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:   0%| | 1.00/12.9M [00:0
#
# Upload file replay.mp4:   0%|                        | 1.00/226k [00:00<?, ?B/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:   0%| | 1.00/1
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth:   0%| | 1.00/
#
#
#
#
# Upload file train_eval_metrics.zip:   0%|           | 1.00/35.4k [00:00<?, ?B/s]
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 15.3MB [00:01, 16.0MB/s]
#
# Upload file replay.mp4: 15.3MB [00:01, 16.0MB/s]
#
#
#
#
# Upload file train_eval_metrics.zip: 15.3MB [00:01, 16.0MB/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 15.3MB [00:02, 8.00MB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip: 30.5MB [00:03, 11.3MB/s]       To https://huggingface.co/GccX11/dqn-SpaceInvadersNoFrameskip-v4
#    fda1909..2ce5c0c  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/GccX11/dqn-SpaceInvadersNoFrameskip-v4
#    fda1909..2ce5c0c  main -> main
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|█| 26.0M/26.0M [00:04<00:0
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 100%|█| 12.9M/12.9M [00:
#
#
# Upload file replay.mp4: 100%|████████████████| 226k/226k [00:04<00:00, 57.8kB/s]
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100%|█| 12.9M/
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100%|█| 431/4
#
#
#
#
#
# Upload file train_eval_metrics.zip: 100%|██| 35.4k/35.4k [00:04<00:00, 9.06kB/s]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/GccX11/dqn-SpaceInvadersNoFrameskip-v4

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga ThomasSimonini  -f logs/

# %% [markdown]
# ###.

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Q-Learning agent using RL-Baselines-3 Zoo. The script above should have displayed a link to a model repository such as https://huggingface.co/ThomasSimonini/dqn-SpaceInvadersNoFrameskip-v4. When you go to this link, you can:
#
# - See a **video preview of your agent** at the right.
# - Click "Files and versions" to see all the files in the repository.
# - Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# - A model card (`README.md` file) which gives a description of the model and the hyperparameters you used.
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# **Compare the results of your agents with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆

# %% [markdown]
# ## Load a powerful trained model 🔥
# - The Stable-Baselines3 team uploaded **more than 150 trained Deep Reinforcement Learning agents on the Hub**.
#
# You can find them here: 👉 https://huggingface.co/sb3
#
# Some examples:
# - Asteroids: https://huggingface.co/sb3/dqn-AsteroidsNoFrameskip-v4
# - Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# - Breakout: https://huggingface.co/sb3/dqn-BreakoutNoFrameskip-v4
# - Road Runner: https://huggingface.co/sb3/dqn-RoadRunnerNoFrameskip-v4
#
# Let's load an agent playing Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# 1. We download the model using `rl_zoo3.load_from_hub`, and place it in a new folder that we can call `rl_trained`

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/

# %% [markdown]
# 2. Let's evaluate if for 5000 timesteps

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/ --no-render

# %% [markdown]
# Why not trying to train your own **Deep Q-Learning Agent playing BeamRiderNoFrameskip-v4? 🏆.**
#
# If you want to try, check https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4#hyperparameters **in the model card, you have the hyperparameters of the trained agent.**

# %% [markdown]
# But finding hyperparameters can be a daunting task. Fortunately, we'll see in the next Unit, how we can **use Optuna for optimizing the Hyperparameters 🔥.**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# Also, **if you want to learn to implement Deep Q-Learning by yourself**, you definitely should look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/atari-envs.gif" alt="Environments"/>

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter!
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and having a solid foundations.
#
# In the next unit, **we’re going to learn about [Optuna](https://optuna.org/)**. One of the most critical task in Deep Reinforcement Learning is to find a good set of training hyperparameters. And Optuna is a library that helps you to automate the search.

# %% [markdown]
# ### This is a course built with you 👷🏿‍♀️
#
# Finally, we want to improve and update the course iteratively with your feedback. If you have some, please fill this form 👉 https://forms.gle/3HgA7bEHwAmmLfwh9
#
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# See you on Bonus unit 2! 🔥

# %% [markdown]
# ### Keep Learning, Stay Awesome 🤗
